# %% [markdown]
# # Convert CSV Table Into HTML Table

# %%
# Import dependencies
import pandas as pd

# %%
# Set file path for reading CSV file
filepath = "Resources/cityweather.csv"

# Read CSV file
city_df = pd.read_csv(filepath)

city_df
# Out:
#                City  Cloudiness Country                 Date  Humidity  \
# 0         Jamestown         100      US  2022-02-12 05:29:42        69
# 1    Sol'vychegodsk         100      RU  2022-02-12 05:29:42        97
# 2             Aswān           0      EG  2022-02-12 05:29:43        72
# 3         Saskylakh          76      RU  2022-02-12 05:27:23        82
# 4             Lagoa          95      PT  2022-02-12 05:29:43        80
# ..              ...         ...     ...                  ...       ...
# 545      Chengzhong         100      CN  2022-02-12 05:33:50        80
# 546        Pacifica          20      US  2022-02-12 05:33:13        65
# 547         Ballina          75      AU  2022-02-12 05:33:51        75
# 548           Nizwá           0      OM  2022-02-12 05:33:51        38
# 549      Wilmington           0      US  2022-02-12 05:32:55        76
#
#      Latitude  Longitude  Max Temperature  Wind Speed
# 0     42.0970   -79.2353            40.08       11.50
# ...

# %%
city_df.to_html("assets/html/table.html")
